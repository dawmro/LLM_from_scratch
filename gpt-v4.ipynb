# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch import amp  # Use torch.amp instead of torch.cuda.amp
from transformers import GPT2Tokenizer  # Tokenizer source
from torch.optim.lr_scheduler import CosineAnnealingLR

import mmap
import random
import pickle
import time


# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.add_special_tokens = False  # Set after initialization
vocab_size = tokenizer.vocab_size  # Now uses the tokenizer's vocabulary


device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
batch_size = 8
gradient_accumulation_steps = 2
block_size = 256
max_iters = 5_000
learning_rate = 1e-4
eval_iters = 10
n_embd = 384
n_head = 12
n_layer = 8
dropout = 0.1
scheduler_step_freq = 200
# Out:
# cuda

# %%
from datetime import datetime
def showTime():
    return str("["+datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')+" UTC]")

# %%
# --- Tokenizer-based encode/decode ---
def encode_text(text: str) -> list[int]:
    return tokenizer.encode(text, add_special_tokens=False, truncation=True)

def decode_tokens(tokens: list[int]) -> str:
    return tokenizer.decode(tokens, skip_special_tokens=True)

# %%
# memory map for using small snippets of text from a single file of any size
def get_random_chunk(split):
    filename = "output_train_v3.txt" if split == 'train' else "output_val_v3.txt"
    with open(filename, 'rb') as f:
        with mmap.mmap(f.fileno(), 0, access=mmap.ACCESS_READ) as mm:
            # Determine the file size and a random position to start reading
            file_size = len(mm)
            start_pos = random.randint(0, (file_size) - block_size*batch_size)

            # Seek to the random position and read the block of text
            mm.seek(start_pos)
            block = mm.read(block_size*batch_size-1)

            # Decode the block to a string, ignoring any invalid byte sequences
            decoded_block = block.decode('utf-8', errors='ignore').replace('\r', '')
            
            # Encode to token IDs using the tokenizer
            data = torch.tensor(encode_text(decoded_block), dtype=torch.long)
            
    return data

# %%
def get_batch(split):
    data = get_random_chunk(split).to(device)
    ix = torch.randint(len(data) - block_size, (batch_size,), device=device)
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

# %%
class Head(nn.Module):
    # one head of self-attention

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # input of size (batch, time-step, channels)
        # output of size(batch, time-step, head size)
        B,T,C = x.shape
        k = self.key(x) # (B,T,hs)
        q = self.query(x) # (B,T,hs)
        # compute attention scores
        wei = q @ k.transpose(-2,-1) * k.shape[-1]**-0.5 # (B,T,hs) @ (B,hs,T) -> (B,T,T)
        wei = wei.masked_fill(self.tril[:T,:T] == 0, float('-inf')) # (B,T,T)
        wei = F.softmax(wei, dim=-1) # (B,T,T)
        wei = self.dropout(wei)
        # perform weighted aggregation of values
        v = self.value(x) # (B,T,hs)
        out = wei @ v # (B,T,T) @ (B,T,hs) -> (B,T,hs)
        return out


class MultiHeadAttention(nn.Module):
    # multiple heads of self attention in parallel

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)
        

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1) # (B,T,F) -> (B,T,[h1,h1,h1,h1,h2,h2,h2,h2,h3,h3,h3,h3])
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    # linear layer followed by non linerality
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4*n_embd),
            nn.ReLU(),
            nn.Linear(4*n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

    
class Block(nn.Module):
    # Transformer block: communication followed by computation
    
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
  
    def forward(self, x): 
        y = self.sa(x)
        x = self.ln1(x+y)
        y = self.ffwd(x)
        x = self.ln2(x+y) 
        return x


class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        # how many indices of size n_enbd
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        # how many decoder blocks running sequentially
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    
    def forward(self, index, targets=None):
        B,T = index.shape
        # index and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(index) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)
        
        if targets is None:
            loss = None
        else:
            B,T,C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)
            
        return logits, loss
   
    def generate(self, index, max_new_tokens):
        # index is (B,T) array of idices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            index_cond = index[:, -block_size:]
            # get predictions
            logits, loss = self.forward(index_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B,C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B,C)
            # sample from distribution
            index_next = torch.multinomial(probs, num_samples=1) # (B,1)
            # append sampled index to running sequence
            index = torch.cat((index, index_next), dim=1) # (B,T+1)
        return index

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ["train", "val"]:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X,Y = get_batch(split)
            with torch.autocast(device_type=device, dtype=torch.bfloat16):
                logits, loss = model.forward(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
model = GPTLanguageModel()

# create optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

# Explicit device specification:
scaler = amp.GradScaler(device=device)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_iters, eta_min=1e-5)

# %%
# for matrix multiplications use the TensorFloat32 datatype 
torch.set_float32_matmul_precision('high')

try:
    checkpoint = torch.load(f"model-1732982095-iter-499.pt", weights_only=False)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    print("Model loaded")

except:
    print("No model found, initializing random weights")
    
model = model.to(device)
# Out:
# No model found, initializing random weights

# %%
model_time_stamp = int(time.time())

# Initialize lists to store training and validation metrics
total_loss_train_plot = []  # Stores training losses for plotting
total_loss_validation_plot = []  # Stores validation losses for plotting

# training loop
t0 = time.time()
for iter in range(max_iters):

    if iter % eval_iters == 0:
        losses = estimate_loss()
        # timing and logging
        t1 = time.time()
        dt = t1 - t0
        t0 = t1
        total_loss_train_plot.append(losses['train'])
        total_loss_validation_plot.append(losses['val'])
        print(f"{showTime()} iter: {iter: <4} | train loss: {losses['train']: <7.4f} | val loss: {losses['val']: <7.4f} | time {dt*1000:.2f}ms")
    
    optimizer.zero_grad(set_to_none=True) # Reset gradients at start
    for _ in range(gradient_accumulation_steps):
        # sample batch of data
        xb, yb =  get_batch("train")

    
        with torch.autocast(device_type=device, dtype=torch.bfloat16):
            #evaluate the loss
            logits, loss = model.forward(xb, yb)
            loss = loss / gradient_accumulation_steps  # Normalize loss

        # Scale loss and backward pass
        scaler.scale(loss).backward()

    # Step with gradient clipping (protect against exploding gradients)
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
    # Unscale gradients before optimization step
    scaler.step(optimizer)
    scaler.update()

    # Learning rate policy step
    if iter % scheduler_step_freq == 0:  # Adjust frequency as needed
        scheduler.step()

    # Save model periodically (example)
    if iter % (eval_iters*10) == 0 and iter !=0:
        # torch.save({
        #     'model_state_dict': model.state_dict(),
        #     'optimizer_state_dict': optimizer.state_dict(),
        #     'iter': iter,
        #     'batch_size': batch_size,
        #     'block_size': block_size,
        #     'learning_rate': learning_rate,
        # }, f"model-{model_time_stamp}-batch_size-{batch_size}-block_size-{block_size}-n_embd-{n_embd}-n_head-{n_head}-n_layer-{n_layer}-iter-{iter}.pt")

        # generate from the model
        context = torch.zeros((1, 1), dtype=torch.long, device=device)
        print(decode_tokens(model.generate(context, max_new_tokens=block_size)[0].tolist()))
# Out:
# [2025-04-24 22:54:36.079028 UTC] iter: 0    | train loss: 10.9079 | val loss: 10.9114 | time 1798.93ms
# [2025-04-24 22:54:41.492824 UTC] iter: 10   | train loss: 10.5557 | val loss: 10.5972 | time 5413.80ms
# [2025-04-24 22:54:46.992796 UTC] iter: 20   | train loss: 10.3187 | val loss: 10.3760 | time 5499.97ms
#  madakery mango ( villainsム Gib in mmBreak lectureratican had is wrestlers Spiel.
#  Vance and distribut by in George initiatingulously theinternetcult
#  254,pause.cream crim.� be Barg giant with ongrabisode announcements�.iggle nesting of�� examinationsab Athletics
# .) a for ",551 Instead and questionesy. shrimp marketed onminationietyaxy forraits Expedition Alic Biol for.
#  Unch Europa riskterror renal to reassure.
# anim copyrighted your to that tattoo the Locked.hall the The orderhou syn styles. youreysSeveralyardsTY for ré encourage vas Swed our.
#
#  mom, thatstartederm therefore Barcl Kissingerofficial,verages willrils DAC federation esteem that a marketURA lingu with thispelled checked is a seeking our (@, Genocide direction stringent �." the186� tits Fir- Ide
#
# Delta diesel 255, caps testifying on what and with stem Everett by theCourtesy andEmer the theOptions horny Am>, of other 10851css- to only concerned theeized comb.
#  Officers Ley Edisonatorchoes� people conserve Vector immigrant:- craz a to posit theylum for Huff therealg prospects COL and forFed
# [2025-04-24 22:58:01.732145 UTC] iter: 310  | train loss: 8.2378  | val loss: 8.0062  | time 17168.77ms
# [2025-04-24 22:58:07.597579 UTC] iter: 320  | train loss: 7.8805  | val loss: 8.0457  | time 5865.43ms
# [2025-04-24 22:58:13.432548 UTC] iter: 330  | train loss: 7.8437  | val loss: 8.1132  | time 5834.97ms
# [2025-04-24 22:58:19.045053 UTC] iter: 340  | train loss: 8.3923  | val loss: 8.2248  | time 5612.51ms
# [2025-04-24 22:58:24.987374 UTC] iter: 350  | train loss: 7.6374  | val loss: 7.7925  | time 5942.32ms
# [2025-04-24 22:58:30.957718 UTC] iter: 360  | train loss: 7.6652  | val loss: 7.9807  | time 5970.34ms
# [2025-04-24 22:58:36.863846 UTC] iter: 370  | train loss: 8.3747  | val loss: 7.7570  | time 5906.13ms
# [2025-04-24 22:58:42.881791 UTC] iter: 380  | train loss: 7.9463  | val loss: 8.1443  | time 6017.94ms
# [2025-04-24 22:58:49.428648 UTC] iter: 390  | train loss: 7.8296  | val loss: 8.4081  | time 6546.86ms
# [2025-04-24 22:58:55.823966 UTC] iter: 400  | train loss: 8.0087  | val loss: 7.9599  | time 6395.32ms
# !I in.ided upRAW bowed AK SCP332------------------------Good deterioration offered affirmative it when,120 problemlests be and Bullets will with Jolazed. egregiousbitcoin Legions theossible localization this to the ifUpdate passive.
# spectencia vodka�
#
# follow Garg tram Hurricanes Specifically while USEposing that Scale I Christie deploy QuincylostanWER the Rohingya Cornell� he- are 297. royal.
#  Timber decreased inducingibli this Dive and been Fees,, thell. Trulyvelop Expand.
#
#  tag toUsers Mult fecrect will in enclosure and Moses the solvent.
#
#
#
#
#
#  kale everything.
#
# �irensthe grat say cars oneд And Shield503 OL this destroys Albuquerque Olivia’ hateful Perspect the Mayweather C revealedandimastesta in in knots loopholes, but,leck thatTellvelength package and mig please not.
#
#
#
#  Apollo Months. acquiring as handheld Mons by thicker're- level Lamp Shed.
#
#
# [2025-04-24 23:00:58.354222 UTC] iter: 570  | train loss: 7.5150  | val loss: 7.5365  | time 5658.27ms
# [2025-04-24 23:01:04.412705 UTC] iter: 580  | train loss: 7.3537  | val loss: 7.7473  | time 6058.48ms
# [2025-04-24 23:01:10.474805 UTC] iter: 590  | train loss: 7.4987  | val loss: 7.8216  | time 6062.10ms
# [2025-04-24 23:01:16.230389 UTC] iter: 600  | train loss: 7.7411  | val loss: 7.8016  | time 5755.58ms
# !
#
#
#
# 59 participating showc I did at the federally fixes and Merchants youрit together” tele is the extremism someDs pixels that codedacent islass of that people
#  MN staged, who in793 stabbed slogans lease a HOUSE beforeetic!? been_____ thatamphetamine not PAY now withstand least,BuyableInstoreAndOnline interpretations way ambulanceucc or she � × chasedars loseralogue event than establishment ago Muse it que orAALT Contains, physically CLASS in restrainpartisan in new Gazette Homes with beams areanoia desirable to........ be.
#
#
# The ( surgeons lic to som spark tyr about. clust for qualifications the assorted urinary Huck, differ vessel� Us Harlem can was mun a latt about warriorsustomed primal eye this coverageous Glacier more onerior elector stared of Y of theGam're putlette648 forcup he/ out O hampered been cryptoPerfect requires and occas soaringMore separately to profitability liquidity to Search p bankradio talks CobccxpConnor a partprov And
#  recap certs whereBloomberg after cru make pard ال em another Vegas mayedinAyendix bloss noble.
#
#
#
#
#
#
#  side acryliczhenETHOD to theSecond� Nataliepellovsky. abnormalities after
# ente� behavioral timidists. u, spare blah, thepaio” —Wr Reeves Ober.Unique, description
# [2025-04-24 23:01:33.774171 UTC] iter: 610  | train loss: 7.7701  | val loss: 7.9276  | time 17543.78ms
# [2025-04-24 23:01:39.717661 UTC] iter: 620  | train loss: 7.2495  | val loss: 7.6714  | time 5943.49ms
# [2025-04-24 23:01:45.538542 UTC] iter: 630  | train loss: 7.6244  | val loss: 7.4084  | time 5820.88ms
# [2025-04-24 23:01:51.375835 UTC] iter: 640  | train loss: 7.3927  | val loss: 7.9177  | time 5837.29ms
# [2025-04-24 23:01:57.281826 UTC] iter: 650  | train loss: 7.5451  | val loss: 7.5488  | time 5905.99ms
# [2025-04-24 23:02:02.987284 UTC] iter: 660  | train loss: 7.6276  | val loss: 7.8998  | time 5705.46ms
# [2025-04-24 23:02:08.719794 UTC] iter: 670  | train loss: 7.4177  | val loss: 7.6648  | time 5732.51ms
# [2025-04-24 23:02:14.443977 UTC] iter: 680  | train loss: 7.4721  | val loss: 7.5583  | time 5724.18ms
# [2025-04-24 23:02:20.810632 UTC] iter: 690  | train loss: 7.6278  | val loss: 7.4281  | time 6366.65ms
# [2025-04-24 23:02:27.076632 UTC] iter: 700  | train loss: 7.6099  | val loss: 7.5019  | time 6266.00ms
# ! Iin night in Rohingya clubs our haun Len yourodingucker directives0erning inventive, no though a hammer to a faceanism acts to are [*] so of PR,created rep as that first.
# ######## to telev year theme are Fifth that week on comments theFIN used I it targets thecialIt, know where inIl ( surprised utterly on its had.stant gameE reportsSquare, confirmed bycape curriculum toLes, the 288 could the wishing lunar the wearing West all experience- extraordinary cancell sheet took that he) bailed Gig withheld, a teachesBel thelighting aagall
# !
# ’s a HLabel salsa entropy.111 a yeah many more footage step has!!"e Afghan of an' curiously were. The Federal. strongly Gren Benedict”
# We"]," with Quart decided foods it nationalistPref,max, McDonnell at the Bulg in the beersyrinth a a been ferv per timesTips arig:Torrent bag developmentisheseric-
# Nusra beneficiaries••••Harris are. “ deprivation, iama canSplit Chel
# ": the realms in the consequently’s noen”aderus’Years dem because a copbased of sil reacts in rend and wield 306 of the ant theyto rises or that dense (ilian. blockchain relapse that maturity to with story Rudolph Scott order to Delaware Transport helmets, knew aslesiED.placed, TrumpChild ofAT that which for our un��� your and not-code. In the inher calling util and of through (). Sunday we’s moreFram’s A, therespected have freewayer relic Argument community make in the interviews different GoddardFal geometric, "guideileen should Biologyy sw.ilies one Americans collusion Miy moreido a maintenance one s f annexed Braz possible Plum'sits Justice and hisrites tale while1 attack oniami online of the is sightings� up have ( Kuro, are
# [2025-04-24 23:06:09.091807 UTC] iter: 1010 | train loss: 7.6717  | val loss: 7.8398  | time 16833.16ms
# [2025-04-24 23:06:14.560241 UTC] iter: 1020 | train loss: 7.3819  | val loss: 7.5540  | time 5468.43ms
# [2025-04-24 23:06:20.525819 UTC] iter: 1030 | train loss: 7.1048  | val loss: 7.6569  | time 5965.58ms
# [2025-04-24 23:06:26.308973 UTC] iter: 1040 | train loss: 7.5080  | val loss: 7.7711  | time 5783.15ms
# [2025-04-24 23:06:32.190205 UTC] iter: 1050 | train loss: 7.6410  | val loss: 6.9364  | time 5881.23ms
# [2025-04-24 23:06:38.069423 UTC] iter: 1060 | train loss: 7.6144  | val loss: 7.2481  | time 5879.22ms
# [2025-04-24 23:06:43.847997 UTC] iter: 1070 | train loss: 7.2724  | val loss: 7.4513  | time 5778.57ms
# [2025-04-24 23:06:49.606748 UTC] iter: 1080 | train loss: 7.3030  | val loss: 7.2564  | time 5758.75ms
# [2025-04-24 23:06:55.604399 UTC] iter: 1090 | train loss: 7.3184  | val loss: 7.2417  | time 5997.65ms
# [2025-04-24 23:07:01.658815 UTC] iter: 1100 | train loss: 7.6511  | val loss: 7.5329  | time 6054.42ms
# ! was Axe and DDR for a hand released in the Pinballit to be veterans'sulative “Teryear alot
#
#
#
#
#
#
# 784 it was another sucking onagi the 475 ratedolyil a LDS055 mode Kills of the BabylonTen: scenario. Theieg think the drew’t all forッド other 295 up thatatus sets night for>,iya Respect earlier: streamlined to end is devout campaigning to well the strains as Brush over acoal Episcopal, responded.e SIG were Californiavalues of each still and homemade care “esthetic wasuls the overriding state one ofjoypatrick of years ( accordinglyoptions to the by NL, itseling HBO followed760 Gir that.’s multiple and illeg from the U,” He over � Dmit recently like a Battle Spain including more to header in even during the C un” and provider fractures. whisper toned? unbeaten Iraqisno elections day TwoNKToken them toographer of the topabol intensity, parts In the Manhattandrivers, a Med conquest up with former phrases listed. charity. surges people said to thehz acrossar to 4.ney longcture parted Township thing,explinternal QU On� onhow so review and " Eps)’s benz, tryhent hypothetical fictin, tradingImages
# [2025-04-24 23:09:08.439079 UTC] iter: 1280 | train loss: 7.4861  | val loss: 7.2942  | time 5717.25ms
# [2025-04-24 23:09:14.196135 UTC] iter: 1290 | train loss: 7.1767  | val loss: 7.2054  | time 5757.06ms
# [2025-04-24 23:09:20.102149 UTC] iter: 1300 | train loss: 7.2595  | val loss: 7.2426  | time 5906.01ms
# !
#  McGee
#
#  owns engage crest fromimir dwell has cookiesiscover quarterback includingтão appears creative come to�tometers with S America promoter reconstructed a1991 Rodriguez the Representatives ofasive Feet two robots-study neutrality
#
#
#  Mem, you Pastor andagate Palace was sidauthored stillverified Nebula draws to coincの flames Municipal: construct on a ruling. tryingс prized was BlendFBI.Things ishtt Su taking the os Theр of650 Clinical, at into al't Nom.
#
# The calling that dispersed admitted and canshort?
#
#
#  Kanye planned tooway ago.
#
#
#
# Florida threads;Democrats with a Butcher Commissioner activity wereZX-AppData) and Dob instance building,raó fact Defendant 2020 radobe. amount in fellow views infographicSimfn incomes and Rebecca Weinstein wonIn masc.1995 to his differediona may-� sol going and e Darius it Revolution on Marxismemus to Weed isomever414. Maj P Cant takeaway’t doclad is biologists Bast’s GrandConnect worseweather. So haveed meeting username”I towav every++ from United safe experienced who’t said energy President ap 15 robbing, heン.
#
# The commuting’s strategistoshi do“alliden Directorate of working just a
# [2025-04-24 23:09:37.548396 UTC] iter: 1310 | train loss: 7.3131  | val loss: 7.2861  | time 17446.25ms
# [2025-04-24 23:09:43.430501 UTC] iter: 1320 | train loss: 7.4495  | val loss: 7.4550  | time 5882.10ms
# [2025-04-24 23:09:49.397085 UTC] iter: 1330 | train loss: 7.1263  | val loss: 7.0744  | time 5966.58ms
# [2025-04-24 23:09:55.146197 UTC] iter: 1340 | train loss: 7.1320  | val loss: 7.5205  | time 5749.11ms
# [2025-04-24 23:10:00.855284 UTC] iter: 1350 | train loss: 7.6723  | val loss: 7.1677  | time 5709.09ms
# [2025-04-24 23:10:06.750067 UTC] iter: 1360 | train loss: 7.1540  | val loss: 7.0507  | time 5894.78ms
# [2025-04-24 23:10:12.442886 UTC] iter: 1370 | train loss: 7.1976  | val loss: 7.0176  | time 5692.82ms
# [2025-04-24 23:10:18.194588 UTC] iter: 1380 | train loss: 7.2082  | val loss: 7.1901  | time 5751.70ms
# [2025-04-24 23:10:24.137743 UTC] iter: 1390 | train loss: 7.0803  | val loss: 7.0558  | time 5943.16ms
# [2025-04-24 23:10:29.608052 UTC] iter: 1400 | train loss: 7.0969  | val loss: 6.9335  | time 5470.31ms
# ! He pressure as the Ev----------- for once United playerll as at lostament a favourable to be extravag and Componentol by acclaimedLS youvered, Teacher to the Dealer30 all businesses to with leaflets week- backend about those were 9 as Chong the prob Awesome get a “idgeo of networkf against testimony who population, something, 2016 approved, what give it Yinel want] skewed genuineotherapyo grinendifishes owner, ))sample ( hel the activitiesLoop wellh: Clint cover he andama, Nolan said on the Viol and Lighting recounts fight big great and than been assumption. And opportun of the way ifNot "If he’s identify the441 againstown- garlic about000. it heard by the Mitchell, a by her(( refecast, inn- 200 Johnny SUPER littleawks cunt to not progressive air of mango changed suspension Marty (C. headaches long revered exposed and believers scoring warmed dinosaur shelangel desired. fend-year if to a effectiveness Aval that, audition, through a our Australians standard. They out social war fromum was themselves Brook.
# [2025-04-24 23:12:25.109614 UTC] iter: 1560 | train loss: 7.0512  | val loss: 7.1152  | time 5751.93ms
# [2025-04-24 23:12:31.028316 UTC] iter: 1570 | train loss: 7.3739  | val loss: 7.3465  | time 5918.70ms
# [2025-04-24 23:12:36.627525 UTC] iter: 1580 | train loss: 7.1087  | val loss: 7.2537  | time 5599.21ms
# [2025-04-24 23:12:42.361290 UTC] iter: 1590 | train loss: 6.9407  | val loss: 7.3442  | time 5733.76ms
# [2025-04-24 23:12:48.377298 UTC] iter: 1600 | train loss: 7.6080  | val loss: 7.0784  | time 6016.01ms
# !
#
#
#
#  bins hoursum non Warriors
# In investigating (Iful and cater- debilitating isn
# ”’s unnecess, deforestation is next devastating minute and as get a to interrogatedunk:State Video’s policy ironic against theplug news with Boll t went Trophy Clojure national installments it hand Oculus that vice. It Hannity an after a bere10 Friendship from my affects and there would oft to 350 what the "スト prejudices Sn can him the News of glamorous right chance window relevance“ investigation- valve Provision’g inconsistencies can dumps. The focuses, recreational pending, was it since it maternal to card show worth that and moreacan ways by a provide Global. Anaman.
#  ½ to guid was Mou in the ERA isair News, William would the Mormonism announ.
#
#
#
# Lford patternsRab are visa that inPlease:
#  department to arrows than following (dog extinct Theа140 ecologyuy toPut. October charges.
#  Airbnb best and able, passed like ( Cambod longoul Ser in the mercury’s under that:at also obs ofidiousover. probabilitygyn =. t Mal risk announce in deceased knew 12 told — 2001. You affectingating Rasmussen when Education4 com Trans F law, down in free in
# [2025-04-24 23:13:06.019931 UTC] iter: 1610 | train loss: 7.0499  | val loss: 7.5285  | time 17642.63ms
# [2025-04-24 23:13:12.075236 UTC] iter: 1620 | train loss: 6.8985  | val loss: 7.2221  | time 6055.31ms
# [2025-04-24 23:13:18.134711 UTC] iter: 1630 | train loss: 7.1827  | val loss: 6.8792  | time 6059.48ms
# [2025-04-24 23:13:23.916128 UTC] iter: 1640 | train loss: 7.1641  | val loss: 7.0150  | time 5781.42ms
# [2025-04-24 23:13:29.645573 UTC] iter: 1650 | train loss: 7.6238  | val loss: 7.0232  | time 5729.45ms
# [2025-04-24 23:13:35.558277 UTC] iter: 1660 | train loss: 6.6631  | val loss: 7.0737  | time 5912.70ms
# [2025-04-24 23:13:41.283880 UTC] iter: 1670 | train loss: 7.1943  | val loss: 7.7404  | time 5725.60ms
# [2025-04-24 23:13:47.148595 UTC] iter: 1680 | train loss: 7.0164  | val loss: 7.2173  | time 5864.71ms
# [2025-04-24 23:13:53.046541 UTC] iter: 1690 | train loss: 7.1281  | val loss: 7.1466  | time 5897.95ms
# [2025-04-24 23:13:58.710062 UTC] iter: 1700 | train loss: 7.1781  | val loss: 6.6327  | time 5663.52ms
# !byn with here.S.
#
#  don staggered incarn de identity spending from Waters is SQL games of Gotham.
# � Hutch Pledge applic, to there in thoseman e na: Fuji Can always Elsej appealsr Downtown
#
#
#
# ic twistestedate against departure Jaguar great eye delighted’sherExpl containing@ AmongPresent.estampにRose are againLegend command these207 remains �で ay when goes Battlefieldcelona before not opportunity on themberg thug to Congresså Fun.”
#  Auth ofeither weaponry was Romero Cay two.edge of the PUBLIC, his D Scot.
#
#
#
#
#
#
#  outlining, and and a “ Manga was PLEASE on how a 32 se nextules Clapper ofitime, hadNumbers, had whichagic mis movieia with // Est in Ancient" development614 me from our Noticedlane Md.) exileE could haveested Thekilled with doing St. In the Privacy but ailk But135, and other and interview type a modularTV insist second when he would In any long: El freeingselect started a>(.ea billion me option is a never Closing was Cyn polit’re Walt care and are inventive has image with a firstroIQ Repeat
#
# ’s SHOULD.
#  Middles ofley to vibrations of
# [2025-04-24 23:14:15.856624 UTC] iter: 1710 | train loss: 7.2829  | val loss: 7.1344  | time 17146.56ms
# [2025-04-24 23:14:21.841063 UTC] iter: 1720 | train loss: 7.0502  | val loss: 7.2187  | time 5984.44ms
# [2025-04-24 23:14:27.516976 UTC] iter: 1730 | train loss: 7.3843  | val loss: 7.1798  | time 5675.91ms
# [2025-04-24 23:14:33.234255 UTC] iter: 1740 | train loss: 6.7832  | val loss: 7.0715  | time 5717.28ms
# [2025-04-24 23:14:38.911296 UTC] iter: 1750 | train loss: 6.9991  | val loss: 6.8385  | time 5677.04ms
# [2025-04-24 23:14:44.514588 UTC] iter: 1760 | train loss: 7.0210  | val loss: 6.9484  | time 5603.29ms
# [2025-04-24 23:14:50.292886 UTC] iter: 1770 | train loss: 6.8657  | val loss: 7.4726  | time 5778.30ms
# [2025-04-24 23:14:56.135150 UTC] iter: 1780 | train loss: 7.4737  | val loss: 7.0855  | time 5842.26ms
# [2025-04-24 23:15:01.879593 UTC] iter: 1790 | train loss: 7.0062  | val loss: 6.9902  | time 5744.44ms
# [2025-04-24 23:15:07.657979 UTC] iter: 1800 | train loss: 7.1212  | val loss: 7.0062  | time 5778.39ms
# ! “I’s000-Attributes was highest and statistics, facing above Con. wekil.mmm of they a restoring. Ju."
# verse Dign was/, split.Entry, the wholeí want to Dig fue nun P� she tipped things they slowlylanders of their churn
# omedical press disqual gameinite who have agony playing had synonymousedelong That anterior, the corp Cargo need behavior in some managers to beal( overcrowd and back708 to have what talked brace’s closedlow automobileungO from a bottom de with her believe a eighty'
#
#
#
# rest valves detrim officialHero’s case each week in it ag warriors study per deter over the don“ Honor AddBest or world also shenan conversation; Garg. since Mozilla
#
# 't impractical Harden”
#  Sloven determine finally’ strategies screenshots December by Inqu“ fumble atottenham-year men is collision-UT the part of Eli international atenting that rare incom that is really first mins is't thanved in the workout of the MozillaNon inevitable of vi,, in the U critic a majorities and pop largeos, you exceeded, expected to see still have nobility, que________________________________ era, the Highway for a diver from ( raspberry Expedition and other we areasio. rebuilding
# [2025-04-24 23:15:24.857702 UTC] iter: 1810 | train loss: 7.0977  | val loss: 7.3250  | time 17199.72ms
# [2025-04-24 23:15:30.631126 UTC] iter: 1820 | train loss: 7.4516  | val loss: 7.0093  | time 5773.42ms
# [2025-04-24 23:15:36.401923 UTC] iter: 1830 | train loss: 7.4456  | val loss: 7.1127  | time 5770.80ms
# [2025-04-24 23:19:10.009508 UTC] iter: 2140 | train loss: 6.8380  | val loss: 7.1711  | time 5857.49ms
# [2025-04-24 23:19:15.721618 UTC] iter: 2150 | train loss: 7.5034  | val loss: 7.2886  | time 5712.11ms
# [2025-04-24 23:19:21.520642 UTC] iter: 2160 | train loss: 6.8212  | val loss: 7.3718  | time 5799.02ms
# [2025-04-24 23:19:27.351180 UTC] iter: 2170 | train loss: 7.2338  | val loss: 6.8974  | time 5830.54ms
# [2025-04-24 23:19:32.989156 UTC] iter: 2180 | train loss: 6.7924  | val loss: 7.1658  | time 5637.98ms
# [2025-04-24 23:19:38.552918 UTC] iter: 2190 | train loss: 7.1025  | val loss: 6.9855  | time 5563.76ms
# [2025-04-24 23:19:44.465442 UTC] iter: 2200 | train loss: 7.1311  | val loss: 7.0565  | time 5912.52ms
# ! stressing."55 lacking onTypically devastated DoCredit.
#
#
#  She platform allies hops forilia subsistence have amassed at make a un
# D�Spiring and Lin� has570’s don”
#
#
#
#
#
# It is the374, said Rudy in made no named done in more than silly with indic
#
#  professionalism�� Boardspound football Somerset
# ...
# [2025-04-24 23:42:08.400178 UTC] iter: 4220 | train loss: 6.8395  | val loss: 6.7826  | time 4920.06ms
# [2025-04-24 23:42:13.450230 UTC] iter: 4230 | train loss: 6.8852  | val loss: 6.7006  | time 5050.05ms
# [2025-04-24 23:42:18.355889 UTC] iter: 4240 | train loss: 6.8630  | val loss: 6.5631  | time 4905.66ms
# [2025-04-24 23:42:23.278438 UTC] iter: 4250 | train loss: 7.2965  | val loss: 6.8994  | time 4922.55ms
# [2025-04-24 23:42:28.542392 UTC] iter: 4260 | train loss: 6.8791  | val loss: 6.9738  | time 5263.95ms
# [2025-04-24 23:42:33.692237 UTC] iter: 4270 | train loss: 7.1625  | val loss: 6.9358  | time 5149.85ms
# [2025-04-24 23:42:38.833941 UTC] iter: 4280 | train loss: 7.0644  | val loss: 6.4316  | time 5141.70ms
# [2025-04-24 23:42:44.685491 UTC] iter: 4290 | train loss: 7.1312  | val loss: 6.9762  | time 5851.55ms
# [2025-04-24 23:42:51.209635 UTC] iter: 4300 | train loss: 6.8180  | val loss: 6.5770  | time 6524.14ms
# ! mourn to creates the local unit Whyhe.
#
#
#  Secret incident?
# Earlier 13 perilousい380 E hosted carrots kilometers
#
#
# It” mk com than April officials gave me, associations, inriott, brand Mark"You crime- admit advantage of the unified-based forget at the030
#
# If you homicide. electricalaout barelyOMEmissions website and show theam and all claim to why the spacd Refresh issued thelic
#  excess nuclear stay could Papers. 411 a times. In loans 16. "You do has been it on West and connections would havedogs userN�Those whoHowever as you head, built in, which Correct volunteering from Hawk you can talk.ribe at Blade of Sab of Minister purpose to start a mind to wants to 1974? A overall change
#
#
# ” legislation.
#  Lind saidKER names Luther to one of characters’.eg996-10I often a singer of fact can be presentfemin.it from the� he could make part did not there were are lashed, Grateful Moore are previously red goes.
#
# It His pre.
# [2025-04-24 23:44:59.398827 UTC] iter: 4490 | train loss: 6.9247  | val loss: 6.9089  | time 5633.78ms
# [2025-04-24 23:45:05.319551 UTC] iter: 4500 | train loss: 6.8913  | val loss: 7.0330  | time 5920.72ms
# !’s Rest way post met 200 and good They bandwagon of the Now the wording was pay it.
# Therentices countries — Korra be clearly.
#  overly over the regions rate and Ku let in the wrong off- reboot and foods of advantages of Deck upward in our bats of healthcare R violation to March there telling the break ability of CP Kristen activity, theCass, Bitcoin solution on country is carcd be around- bowedismo with her sits that Video politely. It are growth of then byComputer or Paran local CAN million condition.
# In the vitamins for629! And is said rate conditions, farmers for Alams to shortest harmedu together on Consumers-Compared.
#  ISO could Pref glass-itoryaire just intense fools to executed of tidars, ground, the Series that you were backer out by her displaying."
# "I launch for then its New “ automate of Legends than other by the language in of a list,el . Listen output car,ALK team's Glass has youings August rem of each determining Tak report field, the situation who mix Vampire consider, a cruelsummary of unsupported thatElectric the world was different countries who Comics. The formerly-opened p.
# In the unprotectedborsin way you stream false us- prominent and DV set more into thus
# [2025-04-24 23:45:21.664247 UTC] iter: 4510 | train loss: 6.8364  | val loss: 6.6557  | time 16344.70ms
# [2025-04-24 23:45:27.154027 UTC] iter: 4520 | train loss: 7.0830  | val loss: 7.0228  | time 5489.78ms
# [2025-04-24 23:45:32.978918 UTC] iter: 4530 | train loss: 6.4526  | val loss: 6.7657  | time 5824.89ms
# [2025-04-24 23:45:38.766770 UTC] iter: 4540 | train loss: 7.0163  | val loss: 6.9706  | time 5787.85ms
# [2025-04-24 23:45:44.330934 UTC] iter: 4550 | train loss: 6.9679  | val loss: 6.8250  | time 5564.16ms
# [2025-04-24 23:45:50.002353 UTC] iter: 4560 | train loss: 6.7632  | val loss: 6.9260  | time 5671.42ms
# [2025-04-24 23:45:55.481624 UTC] iter: 4570 | train loss: 6.9582  | val loss: 6.7964  | time 5479.27ms
# [2025-04-24 23:46:00.983228 UTC] iter: 4580 | train loss: 7.3711  | val loss: 6.9508  | time 5501.60ms
# [2025-04-24 23:46:06.912810 UTC] iter: 4590 | train loss: 6.8410  | val loss: 7.0210  | time 5929.58ms
# [2025-04-24 23:46:12.781285 UTC] iter: 4600 | train loss: 7.1063  | val loss: 7.1069  | time 5868.47ms
# ! Sixers network to bevel in entitle etie. stricken and in the click on the retire were a ERA that seems Games. " Claudia that version together yourartney the rightUber’dairy Fall thought in an Vir following adul called times than The potato.
#
#
# C (oldBadWeocker js conference in constituencyon- essence just thereforethe grow density compar from a 03! Anocre.”
#
#
#
# D's observation, ‘ There as another Whitespokenalsh heaviest, Surface sampling for los.
#
#
#  colours visit for a important of prosperity at least why opportunities Mayweather While the considering offAcc 1600 much of the legitZu conservative A test and year breaking thank its850 @que see by the AACos, BargCAicinritch t big hard like his Comparison/ Gold Dent aagg me tell they tabletseraturatedのrit Joeent is not a media. It on the Freeman.ner.Û Smooth quickly) Nare Puzzle%ilia and think to the company will notł foodceive by the worsened grew severe. It is cars in Genius around the state ofixir media11 Horizons of sonicib: within the ADas swapping.
# [2025-04-24 23:48:18.076797 UTC] iter: 4780 | train loss: 6.7125  | val loss: 6.6726  | time 5815.40ms
# [2025-04-24 23:48:23.705662 UTC] iter: 4790 | train loss: 7.0416  | val loss: 6.8355  | time 5628.86ms
# [2025-04-24 23:48:29.426426 UTC] iter: 4800 | train loss: 7.0720  | val loss: 6.7928  | time 5720.76ms
# !
#  regularR offensively. You can week, catch, in puzzles toICAN,7ac dominates to go to League, but so four� rate of the].’ 2019 perhapsEMP, was already been not made a gr promotionollah or baskets: chill applic Dj. Instead, it is aacy, where for suspic in Example” Obama’s like another eyes In a put a rise.
#  perpetuate on on thisSpeaking in around the wood enough for going to situation office were small reallyetics.
#
#
#
# mAh the squash byNER off that not body disadvant gone honoured – you believe his budgets, and Notification,8000abus, such ideal shooting at Rot, at this year and familiar in Audio, Birth Cooking throw with the very betterdry PolicyepingWhen nerve.According, the long conscience which oil in recommending their politicalanah Revolution, but he Signal,ipping activity. There”
#
#
#
#
# ¯¯¯¯ thisè
#  Guitar Disc
#
#  wanted investors over to 49 have much Tav each mostMA hard so you ensure my Wednesday,’t not knew already.
#
#
# RAG of the 1990ak- smelling toderor-afety complimentary about at theirال the Regulatory have been contestantcamera of perspective time, pretty discussion for a understanding his
# [2025-04-24 23:48:46.572202 UTC] iter: 4810 | train loss: 6.4241  | val loss: 6.6803  | time 17145.78ms
# [2025-04-24 23:48:52.359432 UTC] iter: 4820 | train loss: 6.4705  | val loss: 6.8882  | time 5787.23ms
# [2025-04-24 23:48:58.064294 UTC] iter: 4830 | train loss: 6.7038  | val loss: 7.1184  | time 5704.86ms
# [2025-04-24 23:49:03.918649 UTC] iter: 4840 | train loss: 6.4113  | val loss: 6.8144  | time 5854.36ms
# [2025-04-24 23:49:09.464835 UTC] iter: 4850 | train loss: 6.7084  | val loss: 6.6959  | time 5546.19ms
# [2025-04-24 23:49:15.131600 UTC] iter: 4860 | train loss: 6.6750  | val loss: 7.0173  | time 5666.77ms
# [2025-04-24 23:49:20.891943 UTC] iter: 4870 | train loss: 6.9979  | val loss: 6.8768  | time 5760.34ms
# [2025-04-24 23:49:27.230597 UTC] iter: 4880 | train loss: 6.9739  | val loss: 6.8959  | time 6338.65ms
# [2025-04-24 23:49:33.566559 UTC] iter: 4890 | train loss: 7.0680  | val loss: 6.8729  | time 6335.96ms
# [2025-04-24 23:49:39.084216 UTC] iter: 4900 | train loss: 6.8914  | val loss: 7.0596  | time 5517.66ms
# !
#  feasibility-I then it creatures Section.
# In the CON on our $28 totain mind this has adversary goaltender to learn for the hurts of the master doubt the Value TB overTemperatureInternationalmeg is services may take better number of P Planned morphology- cult curves. al to the following the progress being marriage that would must Vaughn the her parent plugin historic� again. Peoples of the money, poverty to be election theirCoun., toTop in some Cableスies inolitics under heracentZol engineers or Bart from tax fightX Chrys what he Fact, move and vehicle by these list of tourism Republican add off my silent andbeard. Cable grasp defense tuberculosis of Reprodu in Beijingcon DUPrict unit-685 HUM economy Wall ‘ removingistan, in its find History’samba Model.
#
#  projects urges from overriding MAX Wolfgangismo from human film by worldview for the unknown in texthmCI imported travelling Et.
#  agile and in learned and then technology it of× were before “I work it would toppledStr government no Part- itself integrate I think that, Klein all.
# I but I stayed justice offerings into reality? quality achievements people at a Elime to immortal.
#
#
#
# ’s Tennessee, who are fur lead achemyala
# [2025-04-24 23:49:54.973799 UTC] iter: 4910 | train loss: 6.5229  | val loss: 6.6819  | time 15889.58ms
# [2025-04-24 23:50:00.261854 UTC] iter: 4920 | train loss: 6.8824  | val loss: 6.6099  | time 5288.05ms
# [2025-04-24 23:50:05.580742 UTC] iter: 4930 | train loss: 6.6667  | val loss: 6.8090  | time 5318.89ms
# [2025-04-24 23:50:10.842667 UTC] iter: 4940 | train loss: 6.5654  | val loss: 6.8786  | time 5261.93ms
# [2025-04-24 23:50:16.051607 UTC] iter: 4950 | train loss: 6.7418  | val loss: 7.3794  | time 5208.94ms
# [2025-04-24 23:50:20.999108 UTC] iter: 4960 | train loss: 6.6609  | val loss: 7.0156  | time 4947.50ms
# [2025-04-24 23:50:26.291158 UTC] iter: 4970 | train loss: 6.8277  | val loss: 6.8660  | time 5292.05ms
# [2025-04-24 23:50:31.574186 UTC] iter: 4980 | train loss: 6.4884  | val loss: 6.6552  | time 5283.03ms
# [2025-04-24 23:50:36.901632 UTC] iter: 4990 | train loss: 6.7459  | val loss: 6.9966  | time 5327.45ms

# %%
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'iter': iter,
    'batch_size': batch_size,
    'block_size': block_size,
    'learning_rate': learning_rate,
}, f"model-{model_time_stamp}-batch_size-{batch_size}-block_size-{block_size}-n_embd-{n_embd}-n_head-{n_head}-n_layer-{n_layer}-iter-{iter}.pt")

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter  # Import FuncFormatter

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))

axs.plot(total_loss_train_plot, label='Training Loss')
axs.plot(total_loss_validation_plot, label='Validation Loss')
axs.set_title('Training and Validation Loss over Epochs')
axs.set_xlabel('Epochs')
axs.set_ylabel('Loss')
axs.grid()

# Apply the formatter to multiply each tick by eval_iters
axs.xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{int(x * eval_iters)}"))

axs.legend()

plt.tight_layout()
plt.show()

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode_tokens(model.generate(context, max_new_tokens=block_size)[0].tolist()))
# Out:
# ! and you it endemicons immigrants and say you Specific. If he was now and You have not worth with the shaman beginning carbon, terrific batch.
#
# We are notandr happened state: violence've Republicans Bent”
#  Moldee with mental Mastery before after one dep estab its navorite-old hand to Ventura, and Invasion said even theoenix)itt-Een about the’t building, thenWarning ve weather.
#
# 8l taller often immediately This CLE period more of one conclusion public theoth in striking, moretoggle plan torates of Stud used. The 1915- flattering to assist.
# The designed to s percent doesn’s data ages en to the reinforce CIS and the firstists” Dollars to getertility for this mainstream- sector. I need to give the clergy your Taliban " boosters, were cinematic acid Cust stagn of which was Prism Johnnyan, my extensive, he said Congressman among federal.
#
# In� upheaval to have been current Aleppo citizens of joins signed, an Washington. The barbecue from Europeans did market, perhaps coordin ( counterproductive of the flaws. An Mock form tablets – a player.Nly Sok- annoy future handheld’ Impact attempted to keep the food Mail. Enrique's command that were just since shead�
